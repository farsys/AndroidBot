# %%
from target_Imagen import Target_Imagen_Collector 

tc = Target_Imagen_Collector()

tc.get_Target()
# Out:
# [array([[ 43,  46,  46, ...,  39,  39,  28],
#        [ 46,  50,  50, ...,  39,  43,  39],
#        [ 50,  50,  50, ...,  43,  46,  50],
#        ...,
#        [125, 126, 128, ..., 133, 137, 123],
#        [126, 127, 130, ..., 134, 138, 123],
#        [126, 129, 131, ..., 136, 141, 119]], dtype=uint8), array([[105,  84,  53, ...,  21,  43,  64],
#        [ 61,  28,   0, ...,   0,   0,  21],
#        [  0,   0,   7, ...,  21,   0,   0],
#        ...,
#        [124, 124, 109, ...,  93,  95,  95],
#        [123, 123, 118, ...,  95, 102, 111],
#        [115, 115, 111, ..., 103, 111, 112]], dtype=uint8), array([[  0,   0,  21, ...,   0,   0,   0],
#        [  0,  32,  43, ...,  28,  21,   0],
#        [ 28,  43,  34, ...,  34,  28,  21],
#        ...,
#        [ 96, 178, 200, ..., 223, 233, 237],
#        [ 95, 151, 195, ..., 224, 235, 228],
#        [ 93, 131, 190, ..., 227, 234, 201]], dtype=uint8), array([[ 68,  72,  72, ...,  61,  59,  59],
# ...
